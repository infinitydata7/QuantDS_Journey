# %%
# DAY 23: WEEK2 REVIEW + NIFTY PREP
print("🚀 DAY 23: HFT PRODUCTION REVIEW")

day22_pnl = -11.8
risk_budget = 20
success_rate = 85  # Risk adherence

print(f"Day22 RELIANCE: PnL ₹{day22_pnl}")
print(f"Risk used: {abs(day22_pnl)/risk_budget*100:.0f}% ✓")
print("Week2 complete: 6/6 systems live")

# NIFTY futures prep
print("\n📈 MONDAY NIFTY FUTURES:")
print("• Lot: 65 | Margin ~₹1.5L")
print("• JSON NFO tokens ready")
print("• F&O enable → Day25 launch")
# Out:
# 🚀 DAY 23: HFT PRODUCTION REVIEW
# Day22 RELIANCE: PnL ₹-11.8
# Risk used: 59% ✓
# Week2 complete: 6/6 systems live
#
# 📈 MONDAY NIFTY FUTURES:
# • Lot: 65 | Margin ~₹1.5L
# • JSON NFO tokens ready
# • F&O enable → Day25 launch

# %%
import requests
import json

print("📈 NIFTY FUTURES TOKEN PREP")
url = "https://margincalculator.angelone.in/OpenAPI_File/files/OpenAPIScripMaster.json"
data = json.loads(requests.get(url).text)

nfo_nifty = [i for i in data if i['exch_seg']=='NFO' and 'NIFTY' in i['name']]
print(f"Found {len(nfo_nifty)} NIFTY F&O")
print("Sample:", nfo_nifty[0] if nfo_nifty else "None")

equity_reliance = [i for i in data if i['symbol']=='RELIANCE-EQ']
print("RELIANCE-EQ:", equity_reliance[0]['token'] if equity_reliance else "None")
# Out:
# 📈 NIFTY FUTURES TOKEN PREP
# Found 5679 NIFTY F&O
# Sample: {'token': '38320', 'symbol': 'BANKNIFTY26MAY2645900PE', 'name': 'BANKNIFTY', 'expiry': '26MAY2026', 'strike': '4590000.000000', 'lotsize': '30', 'instrumenttype': 'OPTIDX', 'exch_seg': 'NFO', 'tick_size': '5.000000'}
# RELIANCE-EQ: 2885
