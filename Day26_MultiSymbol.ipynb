# %%
# 🚀 DAY 26: MULTI-NIFTY50 HFT PORTFOLIO
print("🎯 3-ASSET HFT: RELIANCE + HDFC + INFY")
print("Day25 GPU → Portfolio scaling")

portfolio = {
    "RELIANCE-EQ": {"token": "2885", "risk": 7},
    "HDFCBANK-EQ": {"token": "11108", "risk": 7},
    "INFY-EQ": {"token": "31838528", "risk": 6}
}

# Day17 correlation sim
import numpy as np
returns = np.random.randn(1000, 3) * 0.01  # Ticks
corr = np.corrcoef(returns.T)
print("Correlation Matrix:")
print(corr.round(2))

# Risk parity allocation
total_risk = 20
weights = np.array([7,7,6]) / total_risk
print(f"Risk Weights: {weights}")

print("\n✅ DAY 26: Multi-symbol HFT ready!")
print("• 3 Nifty50 assets → Diversified alpha")
print("• GitHub Day26 → 26/90")
# Out:
# 🎯 3-ASSET HFT: RELIANCE + HDFC + INFY
# Day25 GPU → Portfolio scaling
# Correlation Matrix:
# [[1.   0.02 0.02]
#  [0.02 1.   0.  ]
#  [0.02 0.   1.  ]]
# Risk Weights: [0.35 0.35 0.3 ]
#
# ✅ DAY 26: Multi-symbol HFT ready!
# • 3 Nifty50 assets → Diversified alpha
# • GitHub Day26 → 26/90
